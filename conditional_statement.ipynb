# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional statements
# 2. `if` statement
# 3. `elif` statement
# 4. `else` statement
# 5. `nested` statement
#
# ```python
# if (condition):
#     statements
#     statements..
# ```
#
# ```python if,else
# if (condition):
#     statement
#     statement...
# else:
#     statements
#     statements...
# ```
#
# ```python if,elif,else
# if (condition):
#     statement
# elif (condition):
#     statement
# elif (condition):
#     statement
# else:
#     statements...
# ```

# %%
#write a program to find the given number is even number
num=int(input("please enter number here:"))
if(num%2==0):
    print(num,"is even number")
# Out:
# please enter number here: 123

# %%
# write a program to find the given number is even number or odd number
number =int(input("please enter number here:"))
if (number%2 ==0):
    print(number,"is even number")
else:
    print(number,"is odd number")
# Out:
# please enter number here: 354646
# 354646 is even number

# %%
#write a program to find the given number is positive or negitive or zero?
number =int(input("please enter number here:"))
if (number>0):
   print(n,"is positive")
elif (number<0):
    print(n,"is negitive")
else:
    print(number,"is zero")
# Out:
# please enter number here: 0
# 0 is zero

# %%
"""
write a program to find the student grades based on marks
1.if students marks in between 100 to 80 then grade is A
2.if students marks in between 79 to 60 then grade is  B
3.if students marks in between 59 to 48 then grade is  C
4.if students marks in between 39 to 25 then grade is  D
5.if students marks in between 24 TO 8 then grade is   FAIL
6."" other than above marks expected output should be please enter correct marks
"""

marks=int(input("enter students marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"is A grade")
elif (marks>=60 and marks<=79):
     print(marks,"is B grade")
elif (marks>=40 and marks<=59):
     print(marks,"is C grade")
elif (marks>=25 and marks<=39):
    print(marks,"is D grade")
elif (marks>=0 and marks<=24):
     print(marks,"is FAIL")
else:
     print(marks,"is not correct marks,please enter correct marks")
# Out:
# enter students marks here: 85
# 85 is A grade

# %%
# write a program to find the largest number from three numbers
# write a program to find the leap year or non leap year
# write a program to check login credentials using conditional statements

# %%
# write a program to find the largest number from three numbers

# Input three numbers
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

# Compare using conditional statements
if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

# Display the result
print("The largest number is:", largest)
Enter first number: 12
Enter second number: 25
Enter third number: 9
The largest number is: 25.0

# %%
# write a program to check login credentials using conditional statements

# Program to check login credentials

# Predefined correct username and password
correct_username = "admin"
correct_password = "12345"

# Input username and password from the user
username = input("Enter username: ")
password = input("Enter password: ")

# Check credentials using conditional statements
if username == correct_username and password == correct_password:
    print("Login successful! Welcome,", username)
elif username != correct_username and password != correct_password:
    print("Both username and password are incorrect.")
elif username != correct_username:
    print("Incorrect username.")
else:
    print("Incorrect password.")
Enter username: admin
Enter password: 12345
Login successful! Welcome, admin

# %%
# write a program to find the leap year or non leap year

# Program to check whether a year is a leap year or not

# Input a year
year = int(input("Enter a year: "))

# Check leap year conditions
if (year % 400 == 0):
    print(year, "is a leap year.")
elif (year % 100 == 0):
    print(year, "is not a leap year.")
elif (year % 4 == 0):
    print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
Enter a year: 2024
2024 is a leap year
